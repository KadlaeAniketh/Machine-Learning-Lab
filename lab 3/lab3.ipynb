# %%
import pandas as pd
df=pd.read_csv("tvmarketing.csv")
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
X = df[['TV']]
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(df.shape)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (200, 2)
# (140, 1) (60, 1) (140,) (60,)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.xlabel("Tv")
plt.ylabel("sales")
plt.title("tv vs sales")
plt.show()

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
model = LinearRegression()
model.fit( X=X_train, y=y_train)
print(model.coef_, model.intercept_)
# Out:
# [0.04768518] 6.915425144054906

# %%
y=7.011085360330938 + 0.0474615 * X

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,model.predict(X_train),color='red')

# %%
model.predict([[100,]])
# Out:
# c:\Users\anike\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.68394284])
